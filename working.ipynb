# %%
import itertools
import math
import random
import requests
from pydantic import BaseModel, constr
from typing import Optional, List
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.formula.api import ols
from scipy.spatial import KDTree
import geopandas as gpd
from shapely.geometry import Point
from IPython.display import display

# %config InlineBackend. figure_format = 'retina'
sns.set()

BASE_URL = 'https://sherlock.aerobotics.com/developers'
API_TOKEN = '1566394169B0EJX2MGAVKVUGGKEMKZBMND9A7VCR'
orchid_id = 216269

# %%
class TreeSurvey(BaseModel):
    id: int
    survey_id: int
    latitude: float
    longitude: float
    radius: float
    ndre: float
    ndvi: float
    height: float
    area: float

class Survey(BaseModel):
    id: int
    hectares: float
    orchard_id: int
    date: str  # Assuming date is in a string format like 'YYYY-MM-DD'
    upload_id: int

class Orchard(BaseModel):
    id: int
    hectares: float
    name: constr(min_length=1, max_length=40)
    farm_id: int
    client_id: int
    polygon: str  # Assuming this is a string representation of the polygon data
    crop_type: constr(min_length=1)

class TreeSurveyResponse(BaseModel):
    count: int
    next: Optional[constr(min_length=1)]
    previous: Optional[constr(min_length=1)]
    results: List[TreeSurvey]

# %%
def get_treesurvey(orchard_id: str, api_token: str) -> TreeSurveyResponse:
    url = f"{BASE_URL}/treesurveys/?survey__orchard_id={orchard_id}"
    headers = {
        "accept": "application/json",
        "Authorization": api_token,
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        try:
            return TreeSurveyResponse.model_validate(response.json())
        except Exception as e:
            raise ValueError(f"Failed to parse response data: {e}")
    else:
        response.raise_for_status()

# Example usage
try:
    orchard_id = "216269"
    api_token = "1566394169B0EJX2MGAVKVUGGKEMKZBMND9A7VCR"
    result = get_treesurvey(orchard_id, api_token)
    print(result)
except Exception as e:
    print(f"Error: {e}")
# Out:
# count=508 next=None previous=None results=[TreeSurvey(id=54733434, survey_id=25319, latitude=-32.3279643, longitude=18.826872, radius=2.0, ndre=0.557, ndvi=0.872, height=3.25, area=22.667), TreeSurvey(id=54733276, survey_id=25319, latitude=-32.3281893, longitude=18.8263421, radius=2.0, ndre=0.559, ndvi=0.881, height=2.422, area=22.662), TreeSurvey(id=54733233, survey_id=25319, latitude=-32.3283205, longitude=18.8256169, radius=2.0, ndre=0.57, ndvi=0.888, height=2.949, area=25.908), TreeSurvey(id=54733009, survey_id=25319, latitude=-32.3287595, longitude=18.8262246, radius=2.0, ndre=0.499, ndvi=0.84, height=2.382, area=16.451), TreeSurvey(id=54733324, survey_id=25319, latitude=-32.3280753, longitude=18.8255473, radius=2.0, ndre=0.555, ndvi=0.869, height=3.178, area=25.914), TreeSurvey(id=54733279, survey_id=25319, latitude=-32.3280162, longitude=18.8263217, radius=2.0, ndre=0.572, ndvi=0.884, height=2.242, area=22.037), TreeSurvey(id=54733259, survey_id=25319, latitude=-32.3279874, longitude=18.8261944, radius=2.0, ndre=0.573, ndvi=0.873, height=2.242, area=22.976), TreeSurvey(id=54733404, survey_id=25319, latitude=-32.3282152, longitude=18.8259209, radius=2.0, ndre=0.592, ndvi=0.884, height=3.022, area=24.134), TreeSurvey(id=54733262, survey_id=25319, latitude=-32.3280811, longitude=18.8263693, radius=2.0, ndre=0.567, ndvi=0.885, height=2.503, area=21.882), TreeSurvey(id=54733310, survey_id=25319, latitude=-32.3281056, longitude=18.8256815, radius=2.0, ndre=0.552, ndvi=0.865, height=2.931, area=25.518), TreeSurvey(id=54733209, survey_id=25319, latitude=-32.3284156, longitude=18.8260619, radius=2.0, ndre=0.552, ndvi=0.883, height=2.949, area=13.588), TreeSurvey(id=54733046, survey_id=25319, latitude=-32.3287805, longitude=18.8260976, radius=2.0, ndre=0.503, ndvi=0.851, height=2.461, area=13.383), TreeSurvey(id=54733237, survey_id=25319, latitude=-32.3280739, longitude=18.8268465, radius=2.0, ndre=0.552, ndvi=0.87, height=3.006, area=12.325), TreeSurvey(id=54733098, survey_id=25319, latitude=-32.3285469, longitude=18.8266393, radius=2.0, ndre=0.542, ndvi=0.865, height=2.832, area=15.081), TreeSurvey(id=54733227, survey_id=25319, latitude=-32.3283032, longitude=18.8255558, radius=2.0, ndre=0.572, ndvi=0.883, height=2.18, area=19.258), TreeSurvey(id=54733183, survey_id=25319, latitude=-32.3283363, longitude=18.8265001, radius=2.0, ndre=0.563, ndvi=0.871, height=2.777, area=22.219), TreeSurvey(id=54733319, survey_id=25319, latitude=-32.328172, longitude=18.825729, radius=2.0, ndre=0.555, ndvi=0.876, height=2.793, area=19.94), TreeSurvey(id=54733104, survey_id=25319, latitude=-32.3287098, longitude=18.8263234, radius=2.0, ndre=0.529, ndvi=0.86, height=3.087, area=13.588), TreeSurvey(id=54733021, survey_id=25319, latitude=-32.3286179, longitude=18.8264124, radius=2.0, ndre=0.51, ndvi=0.847, height=2.97, area=19.062), TreeSurvey(id=54733152, survey_id=25319, latitude=-32.3286795, longitude=18.8256509, radius=2.0, ndre=0.525, ndvi=0.856, height=3.032, area=22.463), TreeSurvey(id=54733311, survey_id=25319, latitude=-32.3281215, longitude=18.8257392, radius=2.0, ndre=0.548, ndvi=0.869, height=2.806, area=21.199), TreeSurvey(id=54733113, survey_id=25319, latitude=-32.3286392, longitude=18.8260042, radius=2.0, ndre=0.561, ndvi=0.87, height=3.342, area=21.948), TreeSurvey(id=54732956, survey_id=25319, latitude=-32.3282368, longitude=18.8257817, radius=2.0, ndre=0.589, ndvi=0.898, height=3.523, area=21.651), TreeSurvey(id=54733141, survey_id=25319, latitude=-32.3286492, longitude=18.8255184, radius=2.0, ndre=0.549, ndvi=0.871, height=2.68, area=20.707), TreeSurvey(id=54733308, survey_id=25319, latitude=-32.3279066, longitude=18.8258055, radius=2.0, ndre=0.581, ndvi=0.89, height=3.189, area=17.748), TreeSurvey(id=54733138, survey_id=25319, latitude=-32.3285671, longitude=18.8253996, radius=2.0, ndre=0.555, ndvi=0.871, height=2.877, area=23.491), TreeSurvey(id=54733315, survey_id=25319, latitude=-32.3281489, longitude=18.82587, radius=2.0, ndr ...

# %%
def treesurvey_to_dataframe(treesurvey_response: TreeSurveyResponse) -> pd.DataFrame:
    data = [treesurvey.model_dump() for treesurvey in treesurvey_response.results]
    df = pd.DataFrame(data)
    return df

# %%
df = treesurvey_to_dataframe(result)
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude, crs="EPSG:4326"))
gdf.to_crs(gdf.estimate_utm_crs(), inplace=True)
# Out:
#            id  survey_id   latitude  longitude  radius   ndre   ndvi  height  \
# 0    54733434      25319 -32.327964  18.826872     2.0  0.557  0.872   3.250
# 1    54733276      25319 -32.328189  18.826342     2.0  0.559  0.881   2.422
# 2    54733233      25319 -32.328320  18.825617     2.0  0.570  0.888   2.949
# 3    54733009      25319 -32.328759  18.826225     2.0  0.499  0.840   2.382
# 4    54733324      25319 -32.328075  18.825547     2.0  0.555  0.869   3.178
# ..        ...        ...        ...        ...     ...    ...    ...     ...
# 503  54733043      25319 -32.328779  18.826644     2.0  0.484  0.817   2.424
# 504  54733370      25319 -32.327872  18.826154     2.0  0.564  0.876   2.707
# 505  54732982      25319 -32.328519  18.825960     2.0  0.560  0.876   3.276
# 506  54733352      25319 -32.327738  18.826340     2.0  0.569  0.887   2.647
# 507  54732979      25319 -32.328491  18.826110     2.0  0.561  0.870   3.275
#
#        area
# 0    22.667
# 1    22.662
# 2    25.908
# 3    16.451
# 4    25.914
# ..      ...
# 503  11.123
# 504  19.976
# 505  23.513
# 506  26.120
# 507  21.643
#
# [508 rows x 9 columns]

# %%
sns.scatterplot(data=gdf, x=gdf.geometry.x, y=gdf.geometry.y, size='radius')
# Out:
# <Axes: xlabel='None', ylabel='None'>

# %%
display(gdf)
gdf.plot()
# Out:
#            id  survey_id   latitude  longitude  radius   ndre   ndvi  height  \
# 0    54733434      25319 -32.327964  18.826872     2.0  0.557  0.872   3.250
# 1    54733276      25319 -32.328189  18.826342     2.0  0.559  0.881   2.422
# 2    54733233      25319 -32.328320  18.825617     2.0  0.570  0.888   2.949
# 3    54733009      25319 -32.328759  18.826225     2.0  0.499  0.840   2.382
# 4    54733324      25319 -32.328075  18.825547     2.0  0.555  0.869   3.178
# ..        ...        ...        ...        ...     ...    ...    ...     ...
# 503  54733043      25319 -32.328779  18.826644     2.0  0.484  0.817   2.424
# 504  54733370      25319 -32.327872  18.826154     2.0  0.564  0.876   2.707
# 505  54732982      25319 -32.328519  18.825960     2.0  0.560  0.876   3.276
# 506  54733352      25319 -32.327738  18.826340     2.0  0.569  0.887   2.647
# 507  54732979      25319 -32.328491  18.826110     2.0  0.561  0.870   3.275
#
#        area                        geometry
# 0    22.667  POINT (295449.295 6421135.967)
# 1    22.662  POINT (295399.913 6421110.006)
# 2    25.908  POINT (295331.933 6421094.072)
# 3    16.451  POINT (295390.134 6421046.556)
# 4    25.914  POINT (295324.828 6421121.127)
# ..      ...                             ...
# 503  11.123  POINT (295429.700 6421045.196)
# 504  19.976  POINT (295381.452 6421144.829)
# 505  23.513  POINT (295364.644 6421072.728)
# 506  26.120  POINT (295398.737 6421160.055)
# 507  21.643  POINT (295378.730 6421076.164)
#
# [508 rows x 10 columns]
# <Axes: >

# %%
# Out:
# 0      295449.294819
# 1      295399.912830
# 2      295331.933120
# 3      295390.134009
# 4      295324.828465
#            ...
# 503    295429.700369
# 504    295381.452012
# 505    295364.643716
# 506    295398.736842
# 507    295378.729968
# Length: 508, dtype: float64

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np

# Example array of points
points = np.column_stack((gdf.geometry.y, gdf.geometry.x))

# Using NearestNeighbors
nbrs = NearestNeighbors(n_neighbors=2, algorithm='auto').fit(points)
distances, indices = nbrs.kneighbors(points)

# indices[:, 1] contains the indices of the nearest neighbors
print("Nearest neighbors (Scikit-Learn):", indices)
plt.hist(distances[:,1])
# Out:
# Nearest neighbors (Scikit-Learn): [[  0 142]
#  [  1 492]
#  [  2 221]
#  ...
#  [505 499]
#  [506 460]
#  [507 347]]
# (array([  4.,   6.,  12.,  30.,  72., 144., 139.,  84.,  11.,   6.]),
#  array([4.55286899, 4.77102386, 4.98917873, 5.2073336 , 5.42548846,
#         5.64364333, 5.8617982 , 6.07995306, 6.29810793, 6.5162628 ,
#         6.73441767]),
#  <BarContainer object of 10 artists>)

# %%
delta = np.subtract(points[indices[:,0]], points[indices[:,1]])
angles = np.arctan2(delta[:,0], delta[:,1])
sns.histplot(angles, bins=100, kde='density')
plt.show()
angles %= (np.pi/2)
sns.histplot(angles, bins=100, kde='density')
plt.vlines(np.median(angles), 0, 100, colors='r')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.set_aspect('equal', 'box')
gdf.plot(ax=ax)

cy, cx = np.mean(points, axis=0)
a = np.median(angles)
b = a - (np.pi/2)
ax.plot([cx, cx+100*np.cos(a)], [cy, cy+100*np.sin(a)], c='g')
ax.plot([cx, cx+100*np.cos(b)], [cy, cy+100*np.sin(b)], c='r')
